# %%
import numpy as np
import random as rd

# %%
grid_size=4

# %%
reward_pots={
    (0,3): 10,
    (1,1): "-1",
    (3,0): 1,
    (3,2): "-20",
    (2,3): -45
}

# %%
rewards=np.zeros((grid_size,grid_size))
for pos,reward in reward_pots.items():
    rewards[pos]=reward
rewards
# Out:
# array([[  0.,   0.,   0.,  10.],
#        [  0.,  -1.,   0.,   0.],
#        [  0.,   0.,   0., -45.],
#        [  1.,   0., -20.,   0.]])

# %%
def get_reward(position):
    return rewards[position]

# %%
get_reward((0,3))
# Out:
# 10.0

# %%
# Define the deterministic transition dynamics
def move(position, action):
    x, y = position
    if action == "up" and x > 0:
        return (x - 1, y)
    elif action == "down" and x < grid_size - 1:
        return (x + 1, y)
    elif action == "left" and y > 0:
        return (x, y - 1)
    elif action == "right" and y < grid_size - 1:
        return (x, y + 1)
    else:
        return position  # If the move is not possible, stay in the same position

# %%
value_func=np.zeros((4,4))

# Value iteration parameters
gamma = 0.7  # Discount factor
theta = 0.00001  # Threshold for convergence
actions = ["up", "down", "left", "right"]

True
# Out:
# True

# %%
def policy_improv(value_func,policy_prev, actions,rewards, gamma, grid_size):
    policy_stable=False
    while not policy_stable:
        policy_stable = True
        new_policy = [["" for _ in range(grid_size)] for _ in range(grid_size)]
        
        for x in range(grid_size):
            for y in range(grid_size):
                state=(x,y)
                old_action = policy_prev[x][y]
                # Find the action that maximizes the value function
                action_values = {}
                for action in actions:
                    new_state = move((x, y), action)
                    action_values[action] = rewards[x, y] + gamma * value_func[new_state]
                    print(f"x:{x} y:{y} and action:{action} action:{action_values[action]}")
                
                best_action = max(action_values, key=action_values.get)
                new_policy[x][y] = best_action

                if old_action != best_action:
                    policy_stable = False
        
        policy_prev = new_policy
    
    return policy_prev

# %%
def policy_eval(value_func,policy,rewards,gamma=0.9,theta=1e-5,grid_size=4): #find v*pi using bellman
    
    while True:
        delta=0
        for x in range(grid_size):
            for y in range(grid_size):
                v=value_func[x,y]
                action=policy[x][y]
                new_state=move((x,y),action)
                value_func[x, y] = rewards[x, y] + gamma * value_func[new_state]
                delta = max(delta, abs(v - value_func[x, y]))
        if delta < theta:
            break
    return value_func

# %%
def policy_iter(rewards, gamma=0.9, theta=1e-5, grid_size=4):
    # Initialize random policy
    actions = ["up", "down", "left", "right"]
    policy = [[np.random.choice(actions) for _ in range(grid_size)] for _ in range(grid_size)]
    value_func = np.zeros((grid_size, grid_size))

    while True:
        # Evaluate the current policy
        value_func = policy_eval(value_func, policy, rewards, gamma, theta, grid_size)
        
        # Improve the policy
        new_policy = policy_improv(value_func, policy,actions, rewards, gamma, grid_size)
        
        # Check if the policy is stable
        if new_policy == policy:
            break
        policy = new_policy

    return policy, value_func

# %%
# Perform policy iteration
optimal_policy, optimal_value_func = policy_iter(rewards, 0.9, theta, grid_size)

# Print the optimal policy and value function
print("Optimal Policy:")
for row in optimal_policy:
    print(row)
print(rewards)
print("\nOptimal Value Function:")
print(optimal_value_func)
# Out:
# x:0 y:0 and action:up action:0.0
# x:0 y:0 and action:down action:-11.809800000000001
# x:0 y:0 and action:left action:0.0
# x:0 y:0 and action:right action:-10.375938000000001
# x:0 y:1 and action:up action:-10.375938000000001
# x:0 y:1 and action:down action:-11.528820000000001
# x:0 y:1 and action:left action:0.0
# x:0 y:1 and action:right action:80.99992612520906
# x:0 y:2 and action:up action:80.99992612520906
# x:0 y:2 and action:down action:72.89993351268815
# x:0 y:2 and action:left action:-10.375938000000001
# x:0 y:2 and action:right action:89.99992612520906
# x:0 y:3 and action:up action:99.99992612520906
# x:0 y:3 and action:down action:90.99993351268816
# x:0 y:3 and action:left action:90.99992612520906
# x:0 y:3 and action:right action:99.99992612520906
# x:1 y:0 and action:up action:0.0
# x:1 y:0 and action:down action:-13.122
# x:1 y:0 and action:left action:-11.809800000000001
# x:1 y:0 and action:right action:-11.528820000000001
# x:1 y:1 and action:up action:-11.375938000000001
# x:1 y:1 and action:down action:-15.58
# x:1 y:1 and action:left action:-12.809800000000001
# x:1 y:1 and action:right action:71.89993351268815
# x:1 y:2 and action:up action:80.99992612520906
# x:1 y:2 and action:down action:-16.2
# x:1 y:2 and action:left action:-11.528820000000001
# x:1 y:2 and action:right action:80.99993351268816
# x:1 y:3 and action:up action:89.99992612520906
# x:1 y:3 and action:down action:-55.080000000000005
# x:1 y:3 and action:left action:72.89993351268815
# x:1 y:3 and action:right action:80.99993351268816
# x:2 y:0 and action:up action:-11.809800000000001
# x:2 y:0 and action:down action:-13.68
# x:2 y:0 and action:left action:-13.122
# x:2 y:0 and action:right action:-14.58
# x:2 y:1 and action:up action:-11.528820000000001
# x:2 y:1 and action:down action:-16.2
# x:2 y:1 and action:left action:-13.122
# x:2 y:1 and action:right action:-16.2
# x:2 y:2 and action:up action:72.89993351268815
# x:2 y:2 and action:down action:-18.0
# x:2 y:2 and action:left action:-14.58
# x:2 y:2 and action:right action:-55.080000000000005
# x:2 y:3 and action:up action:35.99993351268816
# x:2 y:3 and action:down action:-45.0
# x:2 y:3 and action:left action:-61.2
# x:2 y:3 and action:right action:-100.08000000000001
# x:3 y:0 and action:up action:-12.122
# x:3 y:0 and action:down action:-12.68
# x:3 y:0 and action:left action:-12.68
# x:3 y:0 and action:right action:-15.2
# x:3 y:1 and action:up action:-14.58
# x:3 y:1 and action:down action:-16.2
# x:3 y:1 and action:left action:-13.68
# x:3 y:1 and action:right action:-18.0
# x:3 y:2 and action:up action:-36.2
# x:3 y:2 and action:down action:-38.0
# x:3 y:2 and action:left action:-36.2
# x:3 y:2 and action:right action:-20.0
# x:3 y:3 and action:up action:-55.080000000000005
# x:3 y:3 and action:down action:0.0
# x:3 y:3 and action:left action:-18.0
# x:3 y:3 and action:right action:0.0
# x:0 y:0 and action:up action:0.0
# x:0 y:0 and action:down action:-11.809800000000001
# x:0 y:0 and action:left action:0.0
# x:0 y:0 and action:right action:-10.375938000000001
# x:0 y:1 and action:up action:-10.375938000000001
# x:0 y:1 and action:down action:-11.528820000000001
# x:0 y:1 and action:left action:0.0
# x:0 y:1 and action:right action:80.99992612520906
# x:0 y:2 and action:up action:80.99992612520906
# x:0 y:2 and action:down action:72.89993351268815
# x:0 y:2 and action:left action:-10.375938000000001
# x:0 y:2 and action:right action:89.99992612520906
# x:0 y:3 and action:up action:99.99992612520906
# x:0 y:3 and action:down action:90.99993351268816
# x:0 y:3 and action:left action:90.99992612520906
# x:0 y:3 and action:right action:99.99992612520906
# x:1 y:0 and action:up action:0.0
# x:1 y:0 and action:down action:-13.122
# x:1 y:0 and action:left action:-11.809800000000001
# x:1 y:0 and action:right action:-11.528820000000001
# x:1 y:1 and action:up action:-11.375938000000001
# x:1 y:1 and action:down action:-15.58
# x:1 y:1 and action:left action:-12.809800000000001
# x:1 y:1 and action:right action:71.89993351268815
# x:1 y:2 and action:up action:80.99992612520906
# x:1 y:2 and action:down action:-16.2
# x:1 y:2 and action:left action:-11.528820000000001
# x:1 y:2 and action:right action:80.99993351268816
# x:1 y:3 and action:up action:89.99992612520906
# x:1 y:3 and action:down action:-55.080000000000005
# x:1 y:3 and action:left action:72.89993351268815
# x:1 y:3 and action:right action:80.99993351268816
# x:2 y:0 and action:up action:-11.809800000000001
# x:2 y:0 and action:down action:-13.68
# x:2 y:0 and action:left action:-13.122
# x:2 y:0 and action:right action:-14.58
# x:2 y:1 and action:up action:-11.528820000000001
# x:2 y:1 and action:down action:-16.2
# x:2 y:1 and action:left action:-13.122
# x:2 y:1 and action:right action:-16.2
# x:2 y:2 and action:up action:72.89993351268815
# x:2 y:2 and action:down action:-18.0
# x:2 y:2 and action:left action:-14.58
# x:2 y:2 and action:right action:-55.080000000000005
# x:2 y:3 and action:up action:35.99993351268816
# x:2 y:3 and action:down action:-45.0
# x:2 y:3 and action:left action:-61.2
# x:2 y:3 and action:right action:-100.08000000000001
# x:3 y:0 and action:up action:-12.122
# x:3 y:0 and action:down action:-12.68
# x:3 y:0 and action:left action:-12.68
# x:3 y:0 and action:right action:-15.2
# x:3 y:1 and action:up action:-14.58
# x:3 y:1 and action:down action:-16.2
# x:3 y:1 and action:left action:-13.68
# x:3 y:1 and action:right action:-18.0
# x:3 y:2 and action:up action:-36.2
# x:3 y:2 and action:down action:-38.0
# x:3 y:2 and action:left action:-36.2
# x:3 y:2 and action:right action:-20.0
# x:3 y:3 and action:up action:-55.080000000000005
# x:3 y:3 and action:down action:0.0
# x:3 y:3 and action:left action:-18.0
# x:3 y:3 and action:right action:0.0
# x:0 y:0 and action:up action:0.0
# x:0 y:0 and action:down action:0.0
# x:0 y:0 and action:left action:0.0
# x:0 y:0 and action:right action:72.89994016141935
# x:0 y:1 and action:up action:72.89994016141935
# x:0 y:1 and action:down action:64.70994614527741
# x:0 y:1 and action:left action:0.0
# x:0 y:1 and action:right action:80.99994016141935
# x:0 y:2 and action:up action:80.99994016141935
# x:0 y:2 and action:down action:72.89994614527741
# x:0 y:2 and action:left action:72.89994016141935
# x:0 y:2 and action:right action:89.99994016141935
# x:0 y:3 and action:up action:99.99994016141935
# x:0 y:3 and action:down action:90.99994614527742
# x:0 y:3 and action:left action:90.99994016141935
# x:0 y:3 and action:right action:99.99994016141935
# x:1 y:0 and action:up action:0.0
# x:1 y:0 and action:down action:0.0
# x:1 y:0 and action:left action:0.0
# x:1 y:0 and action:right action:64.70994614527741
# x:1 y:1 and action:up action:71.89994016141935
# x:1 y:1 and action:down action:57.238951530749674
# x:1 y:1 and action:left action:-1.0
# x:1 y:1 and action:right action:71.89994614527741
# x:1 y:2 and action:up action:80.99994016141935
# x:1 y:2 and action:down action:65.60995153074967
# x:1 y:2 and action:left action:64.70994614527741
# x:1 y:2 and action:right action:80.99994614527742
# x:1 y:3 and action:up action:89.99994016141935
# x:1 y:3 and action:down action:32.39995153074968
# x:1 y:3 and action:left action:72.89994614527741
# x:1 y:3 and action:right action:80.99994614527742
# x:2 y:0 and action:up action:0.0
# x:2 y:0 and action:down action:0.9
# x:2 y:0 and action:left action:0.0
# x:2 y:0 and action:right action:58.238951530749674
# x:2 y:1 and action:up action:64.70994614527741
# x:2 y:1 and action:down action:0.81
# x:2 y:1 and action:left action:0.0
# x:2 y:1 and action:right action:65.60995153074967
# x:2 y:2 and action:up action:72.89994614527741
# x:2 y:2 and action:down action:-18.0
# x:2 y:2 and action:left action:58.238951530749674
# x:2 y:2 and action:right action:32.39995153074968
# x:2 y:3 and action:up action:35.99994614527742
# x:2 y:3 and action:down action:-45.0
# x:2 y:3 and action:left action:20.60995153074967
# x:2 y:3 and action:right action:-12.600048469250318
# x:3 y:0 and action:up action:1.0
# x:3 y:0 and action:down action:1.9
# x:3 y:0 and action:left action:1.9
# x:3 y:0 and action:right action:1.81
# x:3 y:1 and action:up action:58.238951530749674
# x:3 y:1 and action:down action:0.81
# x:3 y:1 and action:left action:0.9
# x:3 y:1 and action:right action:-18.0
# x:3 y:2 and action:up action:45.60995153074967
# x:3 y:2 and action:down action:-38.0
# x:3 y:2 and action:left action:-19.19
# x:3 y:2 and action:right action:-20.0
# x:3 y:3 and action:up action:32.39995153074968
# x:3 y:3 and action:down action:0.0
# x:3 y:3 and action:left action:-18.0
# x:3 y:3 and action:right action:0.0
# x:0 y:0 and action:up action:0.0
# x:0 y:0 and action:down action:0.0
# x:0 y:0 and action:left action:0.0
# x:0 y:0 and action:right action:72.89994016141935
# x:0 y:1 and action:up action:72.89994016141935
# x:0 y:1 and action:down action:64.70994614527741
# x:0 y:1 and action:left action:0.0
# x:0 y:1 and action:right action:80.99994016141935
# x:0 y:2 and action:up action:80.99994016141935
# x:0 y:2 and action:down action:72.89994614527741
# x:0 y:2 and action:left action:72.89994016141935
# x:0 y:2 and action:right action:89.99994016141935
# x:0 y:3 and action:up action:99.99994016141935
# x:0 y:3 and action:down action:90.99994614527742
# x:0 y:3 and action:left action:90.99994016141935
# x:0 y:3 and action:right action:99.99994016141935
# x:1 y:0 and action:up action:0.0
# x:1 y:0 and action:down action:0.0
# x:1 y:0 and action:left action:0.0
# x:1 y:0 and action:right action:64.70994614527741
# x:1 y:1 and action:up action:71.89994016141935
# x:1 y:1 and action:down action:57.238951530749674
# x:1 y:1 and action:left action:-1.0
# x:1 y:1 and action:right action:71.89994614527741
# x:1 y:2 and action:up action:80.99994016141935
# x:1 y:2 and action:down action:65.60995153074967
# x:1 y:2 and action:left action:64.70994614527741
# x:1 y:2 and action:right action:80.99994614527742
# x:1 y:3 and action:up action:89.99994016141935
# x:1 y:3 and action:down action:32.39995153074968
# x:1 y:3 and action:left action:72.89994614527741
# x:1 y:3 and action:right action:80.99994614527742
# x:2 y:0 and action:up action:0.0
# x:2 y:0 and action:down action:0.9
# x:2 y:0 and action:left action:0.0
# x:2 y:0 and action:right action:58.238951530749674
# x:2 y:1 and action:up action:64.70994614527741
# x:2 y:1 and action:down action:0.81
# x:2 y:1 and action:left action:0.0
# x:2 y:1 and action:right action:65.60995153074967
# x:2 y:2 and action:up action:72.89994614527741
# x:2 y:2 and action:down action:-18.0
# x:2 y:2 and action:left action:58.238951530749674
# x:2 y:2 and action:right action:32.39995153074968
# x:2 y:3 and action:up action:35.99994614527742
# x:2 y:3 and action:down action:-45.0
# x:2 y:3 and action:left action:20.60995153074967
# x:2 y:3 and action:right action:-12.600048469250318
# x:3 y:0 and action:up action:1.0
# x:3 y:0 and action:down action:1.9
# x:3 y:0 and action:left action:1.9
# x:3 y:0 and action:right action:1.81
# x:3 y:1 and action:up action:58.238951530749674
# x:3 y:1 and action:down action:0.81
# x:3 y:1 and action:left action:0.9
# x:3 y:1 and action:right action:-18.0
# x:3 y:2 and action:up action:45.60995153074967
# x:3 y:2 and action:down action:-38.0
# x:3 y:2 and action:left action:-19.19
# x:3 y:2 and action:right action:-20.0
# x:3 y:3 and action:up action:32.39995153074968
# x:3 y:3 and action:down action:0.0
# x:3 y:3 and action:left action:-18.0
# x:3 y:3 and action:right action:0.0
# x:0 y:0 and action:up action:65.60999999944583
# x:0 y:0 and action:down action:58.238999999501246
# x:0 y:0 and action:left action:65.60999999944583
# x:0 y:0 and action:right action:72.89999999944584
# x:0 y:1 and action:up action:72.89999999944584
# x:0 y:1 and action:down action:64.70999999950126
# x:0 y:1 and action:left action:65.60999999944583
# x:0 y:1 and action:right action:80.99999999944583
# x:0 y:2 and action:up action:80.99999999944583
# x:0 y:2 and action:down action:72.89999999950125
# x:0 y:2 and action:left action:72.89999999944584
# x:0 y:2 and action:right action:89.99999999944583
# x:0 y:3 and action:up action:99.99999999944583
# x:0 y:3 and action:down action:90.99999999950126
# x:0 y:3 and action:left action:90.99999999944583
# x:0 y:3 and action:right action:99.99999999944583
# x:1 y:0 and action:up action:65.60999999944583
# x:1 y:0 and action:down action:53.14409999955112
# x:1 y:0 and action:left action:58.238999999501246
# x:1 y:0 and action:right action:64.70999999950126
# x:1 y:1 and action:up action:71.89999999944584
# x:1 y:1 and action:down action:58.04899999955113
# x:1 y:1 and action:left action:57.238999999501246
# x:1 y:1 and action:right action:71.89999999950125
# x:1 y:2 and action:up action:80.99999999944583
# x:1 y:2 and action:down action:65.60999999955112
# x:1 y:2 and action:left action:64.70999999950126
# x:1 y:2 and action:right action:80.99999999950126
# x:1 y:3 and action:up action:89.99999999944583
# x:1 y:3 and action:down action:32.399999999551135
# x:1 y:3 and action:left action:72.89999999950125
# x:1 y:3 and action:right action:80.99999999950126
# x:2 y:0 and action:up action:58.238999999501246
# x:2 y:0 and action:down action:8.999924982764242
# x:2 y:0 and action:left action:53.14409999955112
# x:2 y:0 and action:right action:59.04899999955113
# x:2 y:1 and action:up action:64.70999999950126
# x:2 y:1 and action:down action:53.144099999596015
# x:2 y:1 and action:left action:53.14409999955112
# x:2 y:1 and action:right action:65.60999999955112
# x:2 y:2 and action:up action:72.89999999950125
# x:2 y:2 and action:down action:41.04899999959601
# x:2 y:2 and action:left action:59.04899999955113
# x:2 y:2 and action:right action:32.399999999551135
# x:2 y:3 and action:up action:35.999999999501256
# x:2 y:3 and action:down action:-15.840000000403979
# x:2 y:3 and action:left action:20.60999999955112
# x:2 y:3 and action:right action:-12.600000000448865
# x:3 y:0 and action:up action:54.14409999955112
# x:3 y:0 and action:down action:9.999924982764242
# x:3 y:0 and action:left action:9.999924982764242
# x:3 y:0 and action:right action:54.144099999596015
# x:3 y:1 and action:up action:59.04899999955113
# x:3 y:1 and action:down action:53.144099999596015
# x:3 y:1 and action:left action:8.999924982764242
# x:3 y:1 and action:right action:41.04899999959601
# x:3 y:2 and action:up action:45.60999999955112
# x:3 y:2 and action:down action:21.048999999596013
# x:3 y:2 and action:left action:33.144099999596015
# x:3 y:2 and action:right action:9.159999999596021
# x:3 y:3 and action:up action:32.399999999551135
# x:3 y:3 and action:down action:29.15999999959602
# x:3 y:3 and action:left action:41.04899999959601
# x:3 y:3 and action:right action:29.15999999959602
# x:0 y:0 and action:up action:65.60999999944583
# x:0 y:0 and action:down action:58.238999999501246
# x:0 y:0 and action:left action:65.60999999944583
# x:0 y:0 and action:right action:72.89999999944584
# x:0 y:1 and action:up action:72.89999999944584
# x:0 y:1 and action:down action:64.70999999950126
# x:0 y:1 and action:left action:65.60999999944583
# x:0 y:1 and action:right action:80.99999999944583
# x:0 y:2 and action:up action:80.99999999944583
# x:0 y:2 and action:down action:72.89999999950125
# x:0 y:2 and action:left action:72.89999999944584
# x:0 y:2 and action:right action:89.99999999944583
# x:0 y:3 and action:up action:99.99999999944583
# x:0 y:3 and action:down action:90.99999999950126
# x:0 y:3 and action:left action:90.99999999944583
# x:0 y:3 and action:right action:99.99999999944583
# x:1 y:0 and action:up action:65.60999999944583
# x:1 y:0 and action:down action:53.14409999955112
# x:1 y:0 and action:left action:58.238999999501246
# x:1 y:0 and action:right action:64.70999999950126
# x:1 y:1 and action:up action:71.89999999944584
# x:1 y:1 and action:down action:58.04899999955113
# x:1 y:1 and action:left action:57.238999999501246
# x:1 y:1 and action:right action:71.89999999950125
# x:1 y:2 and action:up action:80.99999999944583
# x:1 y:2 and action:down action:65.60999999955112
# x:1 y:2 and action:left action:64.70999999950126
# x:1 y:2 and action:right action:80.99999999950126
# x:1 y:3 and action:up action:89.99999999944583
# x:1 y:3 and action:down action:32.399999999551135
# x:1 y:3 and action:left action:72.89999999950125
# x:1 y:3 and action:right action:80.99999999950126
# x:2 y:0 and action:up action:58.238999999501246
# x:2 y:0 and action:down action:8.999924982764242
# x:2 y:0 and action:left action:53.14409999955112
# x:2 y:0 and action:right action:59.04899999955113
# x:2 y:1 and action:up action:64.70999999950126
# x:2 y:1 and action:down action:53.144099999596015
# x:2 y:1 and action:left action:53.14409999955112
# x:2 y:1 and action:right action:65.60999999955112
# x:2 y:2 and action:up action:72.89999999950125
# x:2 y:2 and action:down action:41.04899999959601
# x:2 y:2 and action:left action:59.04899999955113
# x:2 y:2 and action:right action:32.399999999551135
# x:2 y:3 and action:up action:35.999999999501256
# x:2 y:3 and action:down action:-15.840000000403979
# x:2 y:3 and action:left action:20.60999999955112
# x:2 y:3 and action:right action:-12.600000000448865
# x:3 y:0 and action:up action:54.14409999955112
# x:3 y:0 and action:down action:9.999924982764242
# x:3 y:0 and action:left action:9.999924982764242
# x:3 y:0 and action:right action:54.144099999596015
# x:3 y:1 and action:up action:59.04899999955113
# x:3 y:1 and action:down action:53.144099999596015
# x:3 y:1 and action:left action:8.999924982764242
# x:3 y:1 and action:right action:41.04899999959601
# x:3 y:2 and action:up action:45.60999999955112
# x:3 y:2 and action:down action:21.048999999596013
# x:3 y:2 and action:left action:33.144099999596015
# x:3 y:2 and action:right action:9.159999999596021
# x:3 y:3 and action:up action:32.399999999551135
# x:3 y:3 and action:down action:29.15999999959602
# x:3 y:3 and action:left action:41.04899999959601
# x:3 y:3 and action:right action:29.15999999959602
# x:0 y:0 and action:up action:65.60999999955112
# x:0 y:0 and action:down action:59.04899999959601
# x:0 y:0 and action:left action:65.60999999955112
# x:0 y:0 and action:right action:72.89999999955113
# x:0 y:1 and action:up action:72.89999999955113
# x:0 y:1 and action:down action:64.70999999959602
# x:0 y:1 and action:left action:65.60999999955112
# x:0 y:1 and action:right action:80.99999999955114
# x:0 y:2 and action:up action:80.99999999955114
# x:0 y:2 and action:down action:72.89999999959602
# x:0 y:2 and action:left action:72.89999999955113
# x:0 y:2 and action:right action:89.99999999955114
# x:0 y:3 and action:up action:99.99999999955114
# x:0 y:3 and action:down action:90.99999999959603
# x:0 y:3 and action:left action:90.99999999955114
# x:0 y:3 and action:right action:99.99999999955114
# x:1 y:0 and action:up action:65.60999999955112
# x:1 y:0 and action:down action:53.14409999963641
# x:1 y:0 and action:left action:59.04899999959601
# x:1 y:0 and action:right action:64.70999999959602
# x:1 y:1 and action:up action:71.89999999955113
# x:1 y:1 and action:down action:58.048999999636415
# x:1 y:1 and action:left action:58.04899999959601
# x:1 y:1 and action:right action:71.89999999959602
# x:1 y:2 and action:up action:80.99999999955114
# x:1 y:2 and action:down action:65.60999999963641
# x:1 y:2 and action:left action:64.70999999959602
# x:1 y:2 and action:right action:80.99999999959603
# x:1 y:3 and action:up action:89.99999999955114
# x:1 y:3 and action:down action:32.39999999963643
# x:1 y:3 and action:left action:72.89999999959602
# x:1 y:3 and action:right action:80.99999999959603
# x:2 y:0 and action:up action:59.04899999959601
# x:2 y:0 and action:down action:48.72968999967277
# x:2 y:0 and action:left action:53.14409999963641
# x:2 y:0 and action:right action:59.048999999636415
# x:2 y:1 and action:up action:64.70999999959602
# x:2 y:1 and action:down action:53.144099999672775
# x:2 y:1 and action:left action:53.14409999963641
# x:2 y:1 and action:right action:65.60999999963641
# x:2 y:2 and action:up action:72.89999999959602
# x:2 y:2 and action:down action:41.04899999967277
# x:2 y:2 and action:left action:59.048999999636415
# x:2 y:2 and action:right action:32.39999999963643
# x:2 y:3 and action:up action:35.99999999959603
# x:2 y:3 and action:down action:-8.0559000002945
# x:2 y:3 and action:left action:20.609999999636415
# x:2 y:3 and action:right action:-12.600000000363572
# x:3 y:0 and action:up action:54.14409999963641
# x:3 y:0 and action:down action:49.72968999967277
# x:3 y:0 and action:left action:49.72968999967277
# x:3 y:0 and action:right action:54.144099999672775
# x:3 y:1 and action:up action:59.048999999636415
# x:3 y:1 and action:down action:53.144099999672775
# x:3 y:1 and action:left action:48.72968999967277
# x:3 y:1 and action:right action:41.04899999967277
# x:3 y:2 and action:up action:45.609999999636415
# x:3 y:2 and action:down action:21.048999999672773
# x:3 y:2 and action:left action:33.144099999672775
# x:3 y:2 and action:right action:16.9440999997055
# x:3 y:3 and action:up action:32.39999999963643
# x:3 y:3 and action:down action:36.9440999997055
# x:3 y:3 and action:left action:41.04899999967277
# x:3 y:3 and action:right action:36.9440999997055
# Optimal Policy:
# ['right', 'right', 'right', 'up']
# ['up', 'right', 'right', 'up']
# ['right', 'right', 'up', 'up']
# ['right', 'up', 'up', 'left']
# [[  0.   0.   0.  10.]
#  [  0.  -1.   0.   0.]
#  [  0.   0.   0. -45.]
#  [  1.   0. -20.   0.]]
#
# Optimal Value Function:
# [[ 72.9     81.      90.     100.    ]
#  [ 65.61    71.9     81.      90.    ]
#  [ 59.049   65.61    72.9     36.    ]
#  [ 54.1441  59.049   45.61    41.049 ]]

# %%
rewards
